# %% [markdown]
# # Introduction to Panda

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

# %%
s = pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.date_range.html
#let's set freq = M, Which stand for Months
dates = pd.date_range('20130101', periods=6, freq='M')
dates
# Out:
# DatetimeIndex(['2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30',
#                '2013-05-31', '2013-06-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.date_range.html
#let's set freq = D, Which stand for Days
dates = pd.date_range('20130101', periods=6, freq='D')
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.235430 -0.261605  0.332938 -0.906662
# 2013-01-02  0.774369  0.055764 -0.579824  0.004687
# 2013-01-03 -0.275228 -0.552088  1.767311 -1.136772
# 2013-01-04  0.399073  0.041602 -1.823515  0.146817
# 2013-01-05 -0.299166 -0.178803 -0.601343 -0.234932
# 2013-01-06  1.038309 -0.252778  0.019807 -0.874783

# %%
df = pd.DataFrame(0, index=dates, columns=list('ABCD'))
df
# Out:
#             A  B  C  D
# 2013-01-01  0  0  0  0
# 2013-01-02  0  0  0  0
# 2013-01-03  0  0  0  0
# 2013-01-04  0  0  0  0
# 2013-01-05  0  0  0  0
# 2013-01-06  0  0  0  0

# %%
dates = pd.date_range('20130101', periods=10, freq='D')
dates
df = pd.DataFrame(np.random.randn(10,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.404824 -0.056745 -0.059137 -0.153146
# 2013-01-02 -0.700958  0.689058 -0.441968 -0.103916
# 2013-01-03  0.829321  0.802494 -0.956699 -0.078792
# 2013-01-04  1.323802  0.466662  0.867193 -0.815568
# 2013-01-05 -2.329616  1.513920  0.275460 -0.550353
# 2013-01-06  0.960997  0.942757  0.122830 -0.631095
# 2013-01-07 -0.720599  0.148346 -0.300632 -0.006572
# 2013-01-08 -0.397356 -1.246608 -0.248504 -0.576201
# 2013-01-09  0.582322 -0.468923  1.190678  0.850606
# 2013-01-10 -1.019819  0.968773  1.458013  0.764717

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06  \
# A   -1.404824   -0.700958    0.829321    1.323802   -2.329616    0.960997
# B   -0.056745    0.689058    0.802494    0.466662    1.513920    0.942757
# C   -0.059137   -0.441968   -0.956699    0.867193    0.275460    0.122830
# D   -0.153146   -0.103916   -0.078792   -0.815568   -0.550353   -0.631095
#
#    2013-01-07  2013-01-08  2013-01-09  2013-01-10
# A   -0.720599   -0.397356    0.582322   -1.019819
# B    0.148346   -1.246608   -0.468923    0.968773
# C   -0.300632   -0.248504    1.190678    1.458013
# D   -0.006572   -0.576201    0.850606    0.764717

# %%
df.A
# Out:
# 2013-01-01   -1.404824
# 2013-01-02   -0.700958
# 2013-01-03    0.829321
# 2013-01-04    1.323802
# 2013-01-05   -2.329616
# 2013-01-06    0.960997
# 2013-01-07   -0.720599
# 2013-01-08   -0.397356
# 2013-01-09    0.582322
# 2013-01-10   -1.019819
# Freq: D, Name: A, dtype: float64

# %%
df.head(2)
# Out:
#                    A         B         C         D
# 2013-01-01 -1.404824 -0.056745 -0.059137 -0.153146
# 2013-01-02 -0.700958  0.689058 -0.441968 -0.103916

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2013-01-09  0.582322 -0.468923  1.190678  0.850606
# 2013-01-10 -1.019819  0.968773  1.458013  0.764717

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-1.40482435, -0.05674452, -0.05913736, -0.15314614],
#        [-0.70095838,  0.6890583 , -0.44196811, -0.10391605],
#        [ 0.8293206 ,  0.80249445, -0.95669861, -0.07879218],
#        [ 1.323802  ,  0.46666237,  0.86719308, -0.81556798],
#        [-2.32961563,  1.51391984,  0.27546043, -0.55035254],
#        [ 0.96099741,  0.94275673,  0.12283032, -0.631095  ],
#        [-0.72059881,  0.14834616, -0.30063173, -0.00657159],
#        [-0.39735581, -1.24660807, -0.24850356, -0.57620095],
#        [ 0.5823222 , -0.46892256,  1.19067816,  0.85060569],
#        [-1.01981881,  0.96877314,  1.45801263,  0.76471652]])

# %%
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.287673   0.375974   0.190724  -0.130032
# std     1.177778   0.805635   0.766593   0.565496
# min    -2.329616  -1.246608  -0.956699  -0.815568
# 25%    -0.945014  -0.005472  -0.287600  -0.569739
# 50%    -0.549157   0.577860   0.031846  -0.128531
# 75%     0.767571   0.907691   0.719260  -0.024627
# max     1.323802   1.513920   1.458013   0.850606

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -0.153146 -0.059137 -0.056745 -1.404824
# 2013-01-02 -0.103916 -0.441968  0.689058 -0.700958
# 2013-01-03 -0.078792 -0.956699  0.802494  0.829321
# 2013-01-04 -0.815568  0.867193  0.466662  1.323802
# 2013-01-05 -0.550353  0.275460  1.513920 -2.329616
# 2013-01-06 -0.631095  0.122830  0.942757  0.960997
# 2013-01-07 -0.006572 -0.300632  0.148346 -0.720599
# 2013-01-08 -0.576201 -0.248504 -1.246608 -0.397356
# 2013-01-09  0.850606  1.190678 -0.468923  0.582322
# 2013-01-10  0.764717  1.458013  0.968773 -1.019819

# %%
df['A']
# Out:
# 2013-01-01   -1.404824
# 2013-01-02   -0.700958
# 2013-01-03    0.829321
# 2013-01-04    1.323802
# 2013-01-05   -2.329616
# 2013-01-06    0.960997
# 2013-01-07   -0.720599
# 2013-01-08   -0.397356
# 2013-01-09    0.582322
# 2013-01-10   -1.019819
# Freq: D, Name: A, dtype: float64

# %%
df[2:5]
# Out:
#                    A         B         C         D
# 2013-01-03  0.829321  0.802494 -0.956699 -0.078792
# 2013-01-04  1.323802  0.466662  0.867193 -0.815568
# 2013-01-05 -2.329616  1.513920  0.275460 -0.550353

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02 -0.700958  0.689058 -0.441968 -0.103916
# 2013-01-03  0.829321  0.802494 -0.956699 -0.078792
# 2013-01-04  1.323802  0.466662  0.867193 -0.815568

# %%
df.loc['20130102':'20130104',['A','B']]
# Out:
#                    A         B
# 2013-01-02 -0.700958  0.689058
# 2013-01-03  0.829321  0.802494
# 2013-01-04  1.323802  0.466662

# %%
df.iloc[3]
# Out:
# A    1.323802
# B    0.466662
# C    0.867193
# D   -0.815568
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.loc[dates[3]]
# Out:
# A    1.323802
# B    0.466662
# C    0.867193
# D   -0.815568
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df2= df.copy()
df2['E'] = ['one','two','three','four','three','six','seven','eight','nine', 'ten']
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -1.404824 -0.056745 -0.059137 -0.153146    one
# 2013-01-02 -0.700958  0.689058 -0.441968 -0.103916    one
# 2013-01-03  0.829321  0.802494 -0.956699 -0.078792    two
# 2013-01-04  1.323802  0.466662  0.867193 -0.815568  three
# 2013-01-05 -2.329616  1.513920  0.275460 -0.550353   four
# 2013-01-06  0.960997  0.942757  0.122830 -0.631095  three
# 2013-01-07 -0.720599  0.148346 -0.300632 -0.006572    two
# 2013-01-08 -0.397356 -1.246608 -0.248504 -0.576201  three
# 2013-01-09  0.582322 -0.468923  1.190678  0.850606   four
# 2013-01-10 -1.019819  0.968773  1.458013  0.764717  three

# %%
import pandas as pd
url = './JSON_DIR/0xf8f005f066a3_Atelier Ten.json'
df = pd.read_json(url, orient='columns')
df.to_csv(r'./DATA_DIR/0xf8f005f066a3_Atelier Ten.txt', header=None, index=None, sep=',', mode='a')

url2 = './JSON_DIR/0xf8f005f0270d_Wei_s Apartment.json'
df2 = pd.read_json(url, orient='columns')
df2.to_csv(r'./DATA_DIR/0xf8f005f0270d_Wei_s Apartment.txt', header=None, index=None, sep=',', mode='a')

url3 = './JSON_DIR/0xf8f005f417ef_CASE #2.json'
df3 = pd.read_json(url, orient='columns')
df3.to_csv(r'./DATA_DIR/0xf8f005f417ef_CASE #2.txt', header=None, index=None, sep=',', mode='a')

url4 = './JSON_DIR/0xf8f005f418d7_CASE #1.json'
df4 = pd.read_json(url, orient='columns')
df4.to_csv(r'./DATA_DIR/0xf8f005f418d7_CASE #1.txt', header=None, index=None, sep=',', mode='a')

url5 = './JSON_DIR/0xf8f005f41863_Simone Bedroom.json'
df5 = pd.read_json(url, orient='columns')
df5.to_csv(r'./DATA_DIR/0xf8f005f41863_Simone Bedroom.txt', header=None, index=None, sep=',', mode='a')

url6 = './JSON_DIR/0xf8f005f41877_Justine_s Apartment.json'
df6 = pd.read_json(url, orient='columns')
df6.to_csv(r'./DATA_DIR/0xf8f005f41877_Justine_s Apartment.txt', header=None, index=None, sep=',', mode='a')

url7 = './JSON_DIR/0xf8f005f41961_CCS.json'
df7 = pd.read_json(url, orient='columns')
df7.to_csv(r'./DATA_DIR/0xf8f005f41961_CCS.txt', header=None, index=None, sep=',', mode='a')


url8 = './JSON_DIR/0xf8f005f41991_CASE (Anna Dyson Office).json'
df8 = pd.read_json(url, orient='columns')
df8.to_csv(r'./DATA_DIR/0xf8f005f41991_CASE (Anna Dyson Office).txt', header=None, index=None, sep=',', mode='a')

# %%
import pandas as pd
url = './JSON_DIR/0xf8f005f41961_CCS.json'
df = pd.read_json(url, orient='columns')
dfn=df.loc[:,["temperature","humidity","co2","dewpoint","pm","timestamp","voc"]]
dfn.to_csv(r'./DATA_DIR/0xf8f005f41961_CCS.txt', header=None, index=None, sep=',', mode='a')

# %%
dfn
# Out:
#         temperature  humidity        co2  dewpoint   pm           timestamp  \
# 0             26852     35224  795664971     10194  217 2016-04-26 20:47:31
# 1             26876     34133  795664971      9744  204 2016-04-26 20:47:54
# 2             27095     33108  795664971      9482  208 2016-04-26 20:48:13
# 3             27151     32566        450      9285  206 2016-04-26 20:48:25
# 4             27263     37234        450     11392  211 2016-04-26 20:48:36
# 5             27306     39321        510     12258  207 2016-04-26 20:48:48
# 6             27303     36161        562     10986  208 2016-04-26 20:49:00
# 7             27279     34703        512     10346  191 2016-04-26 20:49:12
# 8             27271     33114        450      9638  182 2016-04-26 20:49:23
# 9             27236     32508        450      9332  209 2016-04-26 20:49:35
# 10            27228     32353        450      9254  212 2016-04-26 20:49:47
# ...
